# %% [markdown]
# # Pega : FutureSkill, matplotlib 기본기 문제

# %%
import matplotlib.pyplot as plt
# matplotlib의 pyplot모듈을 plt라는 이름으로 사용합니다.




#data
X = [0, 1, 2, 3, 4]
Y = [10, 20, 50, 40, 60]

#plot
plt.plot(X, Y)

plt.savefig('hw_1.jpg')
# 파일 이름으로 그림을 저장합니다.

# %%
import matplotlib.pyplot as plt
# matplotlib의 pyplot모듈을 plt라는 이름으로 사용합니다.

#data
X = [0, 1, 2, 3, 4]
Y = [10, 20, 50, 40, 60]
title = "Revenue (1000 $)"

#plot
'''
code here
'''

plt.savefig(파일 이름)
# 파일 이름으로 그림을 저장합니다.
