# %% [markdown]
# # Google Colaboratory

# %% [markdown]
# ---

# %% [markdown]
# ## Google Colab 사양

# %% [markdown]
# * 플랫폼

# %%
import platform
platform.platform()
# Out:
# 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic'

# %% [markdown]
# * 운영체제

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %% [markdown]
# * CPU 사양

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# * 메모리 사양

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       26696424 kB
# MemFree:        23939864 kB
# MemAvailable:   25709116 kB
# Buffers:          147804 kB
# Cached:          1834572 kB
# SwapCached:            0 kB
# Active:           987816 kB
# Inactive:        1459088 kB
# Active(anon):     414420 kB
# Inactive(anon):      504 kB
# Active(file):     573396 kB
# Inactive(file):  1458584 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              4212 kB
# Writeback:             0 kB
# AnonPages:        464632 kB
# Mapped:           240400 kB
# Shmem:              1200 kB
# KReclaimable:     120988 kB
# Slab:             187596 kB
# SReclaimable:     120988 kB
# SUnreclaim:        66608 kB
# KernelStack:        5728 kB
# PageTables:         6584 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:    13348212 kB
# Committed_AS:    3444356 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       46464 kB
# VmallocChunk:          0 kB
# Percpu:             2848 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      158528 kB
# DirectMap2M:     5081088 kB
# DirectMap1G:    24117248 kB

# %% [markdown]
# * 디스크 사양

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         167G   43G  125G  26% /
# tmpfs            64M     0   64M   0% /dev
# shm              13G     0   13G   0% /dev/shm
# /dev/root       2.0G  1.2G  821M  59% /sbin/docker-init
# tmpfs            13G   36K   13G   1% /var/colab
# /dev/sda1       174G   46G  129G  27% /opt/bin/.nvidia
# tmpfs            13G     0   13G   0% /proc/acpi
# tmpfs            13G     0   13G   0% /proc/scsi
# tmpfs            13G     0   13G   0% /sys/firmware

# %% [markdown]
# * 파이썬 버전

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# ## Google Colab 런타임
# * Colab에서 고성능 하드웨어로 GPU나 TPU 사용 가능
# * 런타임 유형 변경(Change runtime type) 필요
#   + None: CPU만 사용
#   + GPU: 하드웨어 가속으로 GPU 사용
#   + TPU: 하드웨어 가속으로 TPU 사용

# %%
# !nvidia-smi
# Out:
# Tue Dec 21 09:35:56 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 파일 저장 및 다운로드/업로드
#
# * Jupyter Notebook 환경에서 파일 저장 및 다운로드

# %%
# %%writefile test.txt
# text
# Out:
# Writing test.txt

# %%
# !cat test.txt
# Out:
# text

# %%
from google.colab import files
files.download('test.txt')

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-fcdb6215-5ade-48f5-9af1-c98c278c742b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fcdb6215-5ade-48f5-9af1-c98c278c742b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ## Google Drive 연동
#
# * Google Colab은 Google Drive와 `mount`를 통해 쉽게 연동 가능
# * Google Drive에 소스 코드 저장 뿐만 아니라 파일을 열거나 저장 가능

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# MyDrive

# %% [markdown]
# ---

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ## help()
#
# * 파이썬 객체에 대한 요약 정보와 사용법 보기

# %%
help(min)
# Out:
# Help on built-in function min in module builtins:
#
# min(...)
#     min(iterable, *[, default=obj, key=func]) -> value
#     min(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its smallest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the smallest argument.

# %% [markdown]
# ## ?로 설명 보기
#
# * 객체 요약 정보 및 사용법이 있는 docstring 보기

# %%
max?

# %%
li = ['one', 'two', 'three']
li?

# %%
li.count?

# %%
def power(b, n):
  """b 의 n승을 반환"""
  return pow(b, n)

# %%
power?

# %%
power??

# %% [markdown]
# ## 탭(tab) 자동완성
#
# * 객체와 모듈, 인터페이스의 내용을 자동 완성

# %%
li = ['one', 'two', 'three']
li.append
li.clear
# Out:
# <function list.clear>

# %% [markdown]
# ##와일드카드(wildcard) 매칭
#
# * 단어의 중간이나 마지막 글자로 매칭하여 객체나 속성 찾기

# %%
*Error?

# %%
str.*index?

# %% [markdown]
# ## 매직 명령어(magic commands)
#
# * Jupyter Notebook 환경에서 파이썬 파일 저장 및 실행

# %%
# %%writefile test.py
print("Hello Colab")
# Out:
# Writing test.py

# %%
# %run test.py
# Out:
# Hello Colab

# %% [markdown]
# * 코드 실행 시간 측정

# %%
# %%timeit?

# %%
# %timeit li = [n ** n for n in range(10000)]
# Out:
# 1 loop, best of 5: 5.28 s per loop

# %%
# %%timeit
li = []
for n in range(10000):
  li.append(n ** n)
# Out:
# 1 loop, best of 5: 5.2 s per loop

# %% [markdown]
# ## 입력과 출력 이력
#
# * In과 Out 객체를 통해 이전 명령어와 명령어의 출력 결과 보기

# %%
In
# Out:
# ['',
#  'import platform\nplatform.platform()',
#  "get_ipython().system('cat /etc/issue.net')",
#  "get_ipython().system('cat /proc/cpuinfo')",
#  "get_ipython().system('cat /proc/meminfo')",
#  "get_ipython().system('df -h')",
#  "get_ipython().system('python --version')",
#  "get_ipython().system('nvidia-smi')",
#  "get_ipython().run_cell_magic('write', 'test.txt', '')",
#  "get_ipython().run_cell_magic('write', 'test.txt', 'text')",
#  "get_ipython().run_cell_magic('writefile', 'test.txt', 'text')",
#  "get_ipython().getoutput('cat test.text')",
#  "get_ipython().getoutput('cat test.txt')",
#  "get_ipython().system('cat test.txt')",
#  "from google.colab import files\nfiles.download('test.txt')",
#  'upload = files.upload()',
#  'from google.colab import drive',
#  "from google.colab import drive\ndrive.mount('/content/drive')",
#  "get_ipython().system('ls /content/drive')",
#  'help(min)',
#  "get_ipython().magic('pinfo max')",
#  "li = ['one', 'two', 'three']\nget_ipython().magic('pinfo li')",
#  "get_ipython().magic('pinfo li.count')",
#  'def power(b, n):\n  """b 의 n승을 반환"""\n  return pow(b, n)',
#  "get_ipython().magic('pinfo power')",
#  "get_ipython().magic('pinfo2 power')",
#  "li = ['one', 'two', 'three']\nli.append",
#  "li = ['one', 'two', 'three']\nli.append\nli.clear",
#  "get_ipython().magic('psearch *Error')",
#  "get_ipython().magic('psearch str.*index')",
#  'get_ipython().run_cell_magic(\'writefile\', \'test.py\', \'print("Hello Colab")\')',
#  "get_ipython().magic('run test.py')",
#  "get_ipython().magic('pinfo %%timeit')",
#  "get_ipython().magic('timeit li = [n ** for n in range(100000)]')",
#  "get_ipython().magic('timeit li = [n ** n for n in range(100000)]')",
#  "get_ipython().magic('timeit li = [n ** n for n in range(10000)]')",
#  "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')",
#  'In']

# %%
In[26]
# Out:
# "li = ['one', 'two', 'three']\nli.append"

# %%
Out
# Out:
# {1: 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic',
#  11: ['cat: test.text: No such file or directory'],
#  12: ['text'],
#  26: <function list.append>,
#  27: <function list.clear>,
#  37: ['',
#   'import platform\nplatform.platform()',
#   "get_ipython().system('cat /etc/issue.net')",
#   "get_ipython().system('cat /proc/cpuinfo')",
#   "get_ipython().system('cat /proc/meminfo')",
#   "get_ipython().system('df -h')",
#   "get_ipython().system('python --version')",
#   "get_ipython().system('nvidia-smi')",
#   "get_ipython().run_cell_magic('write', 'test.txt', '')",
#   "get_ipython().run_cell_magic('write', 'test.txt', 'text')",
#   "get_ipython().run_cell_magic('writefile', 'test.txt', 'text')",
#   "get_ipython().getoutput('cat test.text')",
#   "get_ipython().getoutput('cat test.txt')",
#   "get_ipython().system('cat test.txt')",
#   "from google.colab import files\nfiles.download('test.txt')",
#   'upload = files.upload()',
#   'from google.colab import drive',
#   "from google.colab import drive\ndrive.mount('/content/drive')",
#   "get_ipython().system('ls /content/drive')",
#   'help(min)',
#   "get_ipython().magic('pinfo max')",
#   "li = ['one', 'two', 'three']\nget_ipython().magic('pinfo li')",
#   "get_ipython().magic('pinfo li.count')",
#   'def power(b, n):\n  """b 의 n승을 반환"""\n  return pow(b, n)',
#   "get_ipython().magic('pinfo power')",
#   "get_ipython().magic('pinfo2 power')",
#   "li = ['one', 'two', 'three']\nli.append",
#   "li = ['one', 'two', 'three']\nli.append\nli.clear",
#   "get_ipython().magic('psearch *Error')",
#   "get_ipython().magic('psearch str.*index')",
#   'get_ipython().run_cell_magic(\'writefile\', \'test.py\', \'print("Hello Colab")\')',
#   "get_ipython().magic('run test.py')",
#   "get_ipython().magic('pinfo %%timeit')",
#   "get_ipython().magic('timeit li = [n ** for n in range(100000)]')",
#   "get_ipython().magic('timeit li = [n ** n for n in range(100000)]')",
#   "get_ipython().magic('timeit li = [n ** n for n in range(10000)]')",
#   "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')",
#   'In',
#   'In[26]',
#   'Out[2]',
#   'Out'],
#  38: "li = ['one', 'two', 'three']\nli.append"}

# %%
Out[38]
# Out:
# "li = ['one', 'two', 'three']\nli.append"

# %%
print("In[33]" + In[33] + "\nOut[38]" + Out[38])
# Out:
# In[33]get_ipython().magic('timeit li = [n ** for n in range(100000)]')
# Out[38]li = ['one', 'two', 'three']
# li.append

# %% [markdown]
# * `_`를 이용해 이전 출력값 출력하기

# %%
print(_)
# Out:
# li = ['one', 'two', 'three']
# li.append

# %%
print(__)
# Out:
# li = ['one', 'two', 'three']
# li.append

# %%
print(___)
# Out:
# ['', 'import platform\nplatform.platform()', "get_ipython().system('cat /etc/issue.net')", "get_ipython().system('cat /proc/cpuinfo')", "get_ipython().system('cat /proc/meminfo')", "get_ipython().system('df -h')", "get_ipython().system('python --version')", "get_ipython().system('nvidia-smi')", "get_ipython().run_cell_magic('write', 'test.txt', '')", "get_ipython().run_cell_magic('write', 'test.txt', 'text')", "get_ipython().run_cell_magic('writefile', 'test.txt', 'text')", "get_ipython().getoutput('cat test.text')", "get_ipython().getoutput('cat test.txt')", "get_ipython().system('cat test.txt')", "from google.colab import files\nfiles.download('test.txt')", 'upload = files.upload()', 'from google.colab import drive', "from google.colab import drive\ndrive.mount('/content/drive')", "get_ipython().system('ls /content/drive')", 'help(min)', "get_ipython().magic('pinfo max')", "li = ['one', 'two', 'three']\nget_ipython().magic('pinfo li')", "get_ipython().magic('pinfo li.count')", 'def power(b, n):\n  """b 의 n승을 반환"""\n  return pow(b, n)', "get_ipython().magic('pinfo power')", "get_ipython().magic('pinfo2 power')", "li = ['one', 'two', 'three']\nli.append", "li = ['one', 'two', 'three']\nli.append\nli.clear", "get_ipython().magic('psearch *Error')", "get_ipython().magic('psearch str.*index')", 'get_ipython().run_cell_magic(\'writefile\', \'test.py\', \'print("Hello Colab")\')', "get_ipython().magic('run test.py')", "get_ipython().magic('pinfo %%timeit')", "get_ipython().magic('timeit li = [n ** for n in range(100000)]')", "get_ipython().magic('timeit li = [n ** n for n in range(100000)]')", "get_ipython().magic('timeit li = [n ** n for n in range(10000)]')", "get_ipython().run_cell_magic('timeit', '', 'li = []\\nfor n in range(10000):\\n  li.append(n ** n)')", 'In', 'In[26]', 'Out[2]', 'Out', 'Out[31]', 'Out[38]', 'print("In[33]" + In[33] + "\\nOut[38]" + Out[38])', 'print(_)', 'prnt(__)', 'print(___)']

# %%
_5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-4bcae68e58e3> in <module>()
# ----> 1 _5
#
# NameError: name '_5' is not defined

# %% [markdown]
# * `%history`를 이용한 입력 이력 살펴보기

# %%
# %history -n 1-7
# Out:
#    1:
# import platform
# platform.platform()
#    2: !cat /etc/issue.net
#    3: !cat /proc/cpuinfo
#    4: !cat /proc/meminfo
#    5: !df -h
#    6: !python --version
#    7: !nvidia-smi

# %% [markdown]
# * `%rerun`을 이용해 이전 입력 이력 다시 실행

# %%
# %rerun
# Out:
# === Executing: ===
# %history -n 1-7
# === Output: ===
#    1:
# import platform
# platform.platform()
#    2: !cat /etc/issue.net
#    3: !cat /proc/cpuinfo
#    4: !cat /proc/meminfo
#    5: !df -h
#    6: !python --version
#    7: !nvidia-smi

# %% [markdown]
# ## 셸 명령어
#
# * 텍스트 기반의 셸 명령어 처리
# * `!` 문자를 명령어 앞에 붙여서 셸 명령어 사용 가능

# %% [markdown]
# * `ls`: 디렉토리 리스트 보기

# %%
# !ls
# Out:
# drive  sample_data  test.py  test.txt

# %% [markdown]
# * `pwd`: 현재 경로 보기

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# * `cd`: 디렉토리 변경
# * IPython에서는 임시 셸에서 실행

# %%
# !cd sample_data/ && ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# * `%cd`: 지속적인 디렉토리 변경

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %% [markdown]
# * `echo`: 화면 출력

# %%
# !echo "Shell"
# Out:
# Shell

# %% [markdown]
# * `mkdir`: 디렉토리 생성

# %%
# !mkdir tmp

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv	     tmp
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# * `cat`: 파일 보기

# %%
# !cat README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %% [markdown]
# * `cp`: 디렉토리/파일 복사

# %%
# !cp README.md tmp/

# %%
# !ls tmp/
# Out:
# README.md

# %% [markdown]
# * `rm`: 디렉토리/파일 삭제

# %%
# !rm -r tmp
#-r은 recurrent의 약자

# %% [markdown]
# ---

# %% [markdown]
# # 마크다운(Markdown)
#
# * 문법이 간단하고, 사용이 쉬움

# %% [markdown]
# ## 제목(Heading) 표시

# %% [markdown]
# # heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6

# %% [markdown]
# ## 목록(List) 구성

# %% [markdown]
# 1. 첫째
# 2. 둘째
# 3. 셋째
# 4.

# %% [markdown]
# ## 폰트 스타일(Font Style)

# %% [markdown]
# **bold**
# __bold
# *italic*
# _italic
# ~~strike~~
# <u>underber</u>

# %% [markdown]
# ## 인용구

# %% [markdown]
# > ref
# >> ref
# >>> ref

# %% [markdown]
# [링크 텍스트](https:// [링크 텍스트](https://))## 링크

# %% [markdown]
# [Google](https://google)## 링크

# %% [markdown]
# ## 이미지

# %% [markdown]
# ## 수평선

# %% [markdown]
# ---

# %% [markdown]
# ## 표

# %% [markdown]
# | C1 | C2 | C3  |
# |:---|---:|:---:|
# | D1 | D2 | D3 |

# %% [markdown]
# ## 코드

# %% [markdown]
# 'inline code'
#
# '''python
# def power(b, n):
#    return pow(b, n)
# '''
