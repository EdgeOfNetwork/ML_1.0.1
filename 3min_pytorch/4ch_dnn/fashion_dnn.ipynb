# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils import data
from torchvision import transforms, datasets

# %% [markdown]
# TODO :
#
# 1. 모듈화
# 2. GPU사용 부분에 대한 try catch 예외처리
# 3. 모듈화 and argparse

# %%
transform = transforms.Compose([
                                transforms.ToTensor()
])

# %%
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")

#TODO : GPU사용에 대한 try catch 예외처리

# %%
EPOCHS = 30
BATCH_SIZE = 64

# %%
trainset = datasets.FashionMNIST(
    root = '/content/drive/MyDrive/torch_tutorial/3min_torch/4ch_dnn/.data',
    train = True,
    download = True,
    transform = transform
)

# %%
testset = datasets.FashionMNIST(
    root = '/content/drive/MyDrive/torch_tutorial/3min_torch/4ch_dnn/.data',
    train = False,
    download = True,
    transform = transform
)

# %%
train_loader = data.DataLoader(
    dataset = trainset,
    batch_size = BATCH_SIZE,
    shuffle = True,
)

test_loader = data.DataLoader(
    dataset = testset,
    batch_size = BATCH_SIZE,
    shuffle = True,
)

# %%
class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = nn.Linear(784, 256)
    self.fc2 = nn.Linear(256, 128)
    self.fc3 = nn.Linear(128, 10)

  def forward(self, x):
    x = x.view(-1, 784)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x

# %%
model = Net().to(DEVICE)

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
def train(model, train_loader, optimizer):
  model.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    data, target = data.to(DEVICE), target.to(DEVICE)
    optimizer.zero_grad()
    output = model(data)
    loss = F.cross_entropy(output, target)
    loss.backward()
    optimizer.step()

# %%
def evaluate(model, test_loader):
  model.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      data, target = data.to(DEVICE), target.to(DEVICE)
      output = model(data)

      #모든 오차를 더한다
      test_loss += F.cross_entropy(output, target, reduction='sum').item()

      #가장 큰 값을 가진 클래스가 모델의 예측
      #예측과 정답을 비교하여 일치할 경우 correct에 1을 더한다.
      pred = output.max(1, keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

      #모델의 전체 데이터셋에 대한 오차와 맞힌 개수의 합이 구해짐
      #이 값들을 test_set의 데이터 수로 나눠 평균을 구함.

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
  train(model, train_loader, optimizer)
  test_loss, test_accuracy = evaluate(model, test_loader)

  print('[{}] Test Loss: {:.4f}, Accuracy: {:.2f}%'.format(epoch, test_loss, test_accuracy))
# Out:
# [1] Test Loss: 0.6555, Accuracy: 76.55%
# [2] Test Loss: 0.5839, Accuracy: 78.94%
# [3] Test Loss: 0.5679, Accuracy: 78.97%
# [4] Test Loss: 0.5182, Accuracy: 81.77%
# [5] Test Loss: 0.5250, Accuracy: 81.55%
# [6] Test Loss: 0.4825, Accuracy: 82.87%
# [7] Test Loss: 0.4979, Accuracy: 82.07%
# [8] Test Loss: 0.4949, Accuracy: 81.79%
# [9] Test Loss: 0.4999, Accuracy: 82.68%
# [10] Test Loss: 0.4582, Accuracy: 83.88%
# [11] Test Loss: 0.4377, Accuracy: 84.44%
# [12] Test Loss: 0.4849, Accuracy: 81.99%
# [13] Test Loss: 0.4252, Accuracy: 84.92%
# [14] Test Loss: 0.4463, Accuracy: 84.53%
# [15] Test Loss: 0.4452, Accuracy: 84.03%
# [16] Test Loss: 0.4244, Accuracy: 84.77%
# [17] Test Loss: 0.4427, Accuracy: 84.14%
# [18] Test Loss: 0.4017, Accuracy: 85.98%
# [19] Test Loss: 0.4221, Accuracy: 85.40%
# [20] Test Loss: 0.4092, Accuracy: 85.46%
# [21] Test Loss: 0.3959, Accuracy: 86.14%
# [22] Test Loss: 0.3879, Accuracy: 86.40%
# [23] Test Loss: 0.3935, Accuracy: 86.06%
# ...
