# %% [markdown]
# https://docs.opencv.org/master/dd/d53/tutorial_py_depthmap.html
#
# to create a depth map from stereo images.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# https://vision.middlebury.edu/stereo/submit3/datasets/test.php
#
# newkuba image로 해보고 싶은데 왜 다운로드가 안되는걸까

# %%
imgL = cv2.imread('im0.png', 0)
imgR = cv2.imread('im1.png', 0)

stereo = cv2.StereoBM_create(numDisparities=16, blockSize=15)
disparity = stereo.compute(imgL, imgR)
plt.imshow(disparity, 'gray')
plt.show()
